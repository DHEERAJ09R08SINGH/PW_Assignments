# %% [markdown]
# ### Consider following code to answer further questions:

# %%
import pandas as pd

course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']

duration = [2,3,6,4]

df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})

# %%
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %% [markdown]
# #### Q1. Write a code to print the data present in the second row of the dataframe, df.

# %%
df[1:2]
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %%
# or
print(df.iloc[1])
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [markdown]
# #### Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?
#
# Ans:
#
# | Feature          | `loc`       | `iloc`            |
# | ---------------- | ----------- | ----------------- |
# | Based On         | Labels      | Integer positions |
# | Row Selection    | Index name  | Index number      |
# | Column Selection | Column name | Column position   |
# | Slice End        | Included    | Excluded          |
# | Boolean indexing | Yes         | Yes               |

# %% [markdown]
# #### Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df then find the output for both new_df.loc[2] and new_df.iloc[2]. Did you observe any difference in both the outputs? If so then explain it.

# %%
new_df = df.reindex([3,0,1,2])

# %%
new_df.loc[2]
# loc works with label
# It looks for index label 2 # Index 2 → Big Data, 6
# Out:
# course_name    Big Data
# duration              6
# Name: 2, dtype: object

# %%
new_df.iloc[2]
# iloc works with position
# It selects the 3rd row (position starts from 0) # Position 2 → Machine Learning, 3
# Out:
# course_name    Machine Learning
# duration                      3
# Name: 1, dtype: object

# %% [markdown]
# ### Consider the below code to answer further questions:

# %%
import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %%
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.472787  0.770262  0.486125  0.149397  0.485185  0.670273
# 2  0.745084  0.110375  0.193331  0.915160  0.439002  0.627850
# 3  0.860000  0.746137  0.425315  0.105725  0.305688  0.727060
# 4  0.152384  0.818112  0.500398  0.157077  0.600235  0.871246
# 5  0.661143  0.507560  0.509629  0.385712  0.396886  0.057097
# 6  0.799850  0.279725  0.289228  0.563579  0.948103  0.605383

# %% [markdown]
# Q4. Write a code to find the following statistical measurements for the above dataframe df1:
#
# (i) mean of each and every column present in the dataframe.
#
# (ii) standard deviation of column, ‘column_2’

# %%
df1['column_1'].mean()#1)col1->col6
# Out:
# np.float64(0.6152080494945706)

# %%
df1['column_2'].mean()
# Out:
# np.float64(0.538695139324919)

# %%
df1['column_3'].mean()
# Out:
# np.float64(0.40067122603368177)

# %%
df1['column_4'].mean()
# Out:
# np.float64(0.3794416625514015)

# %%
df1['column_5'].mean()
# Out:
# np.float64(0.5291831991039008)

# %%
df1['column_6'].mean()
# Out:
# np.float64(0.5931513718291161)

# %%
df1['column_2'].std() # 2)std
# Out:
# 0.2919662870898719

# %% [markdown]
# ### Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the mean of column, column_2. If you are getting errors in executing it then explain why. [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

# %%
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.472787  0.770262  0.486125  0.149397  0.485185  0.670273
# 2  0.745084  0.110375  0.193331  0.915160  0.439002  0.627850
# 3  0.860000  0.746137  0.425315  0.105725  0.305688  0.727060
# 4  0.152384  0.818112  0.500398  0.157077  0.600235  0.871246
# 5  0.661143  0.507560  0.509629  0.385712  0.396886  0.057097
# 6  0.799850  0.279725  0.289228  0.563579  0.948103  0.605383

# %%
df1.loc[2, 'column_2'] = 'string_data'
# Out:
# /tmp/ipython-input-2207565390.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'string_data' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df1.loc[2, 'column_2'] = 'string_data'

# %% [markdown]
# df1['column_2'].mean() # error # Python is trying to add a float (number) and a string (text) together — which is not allowed.

# %% [markdown]
# ### Q6. What do you understand about the windows function in pandas and list the types of windows functions?
#
# Ans:
#
# In Pandas, a window function performs calculations over a group of rows that are related to the current row.
#
# Instead of calculating on the entire column (like mean()), window functions calculate on a subset (window) of data.
#
# They are mainly used in:
#
# 📈 Time series analysis
#
# 📊 Moving averages
#
# 📉 Rolling statistics
#
# 📌 Trend analysis
#
# Types of Window Functions in Pandas:
#
# 1)Rolling Window Functions:
# Used for fixed-size moving window calculations.
#
# df.rolling(window=3)
#
# 2)Expanding Window Functions:
# Window keeps expanding from start to current row.
#
# df.expanding()
#
# 3)Exponential Weighted Window (EWM):
# Gives more weight to recent values.
#
# df.ewm(span=3)

# %% [markdown]
# ### Q7. Write a code to print only the current month and year at the time of answering this question. [Hint: Use pandas.datetime function]
#
# Ans:
#
# To print only the current month and year using Pandas, we can use the pd.Timestamp (since pandas.datetime is deprecated in newer versions).

# %%
import pandas as pd

current_date = pd.Timestamp.now()

print(current_date.strftime("%B %Y"))
# Out:
# February 2026

# %% [markdown]
# ### Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and calculates the difference between them in days, hours, and minutes using Pandas time delta. The program should prompt the user to enter the dates and display the result.

# %%
import pandas as pd

# Taking input from user
date1 = input("Enter first date (YYYY-MM-DD): ")
date2 = input("Enter second date (YYYY-MM-DD): ")

# Converting string input to datetime
d1 = pd.to_datetime(date1)
d2 = pd.to_datetime(date2)

# Calculate difference
difference = d2 - d1

# Extract days, hours, minutes
days = difference.days
hours = difference.total_seconds() // 3600
minutes = difference.total_seconds() // 60

# Display result
print("\nDifference Between Dates:")
print("Days:", abs(days))
print("Hours:", abs(int(hours)))
print("Minutes:", abs(int(minutes)))
# Out:
# Enter first date (YYYY-MM-DD): 20240211
# Enter second date (YYYY-MM-DD): 20240311
#
# Difference Between Dates:
# Days: 29
# Hours: 696
# Minutes: 41760

# %% [markdown]
# ### Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified column to a categorical data type. The program should prompt the user to enter the file path, column name, and category order, and then display the sorted data.

# %%
import pandas as pd

# Take user inputs
file_path = input("Enter CSV file path: ")
column_name = input("Enter column name to convert into category: ")
category_order = input("Enter category order (comma-separated): ")

# Convert category order string into list
category_list = [cat.strip() for cat in category_order.split(",")]

# Read CSV file
df = pd.read_csv(file_path)

# Convert column to categorical with specified order
df[column_name] = pd.Categorical(
    df[column_name],
    categories=category_list,
    ordered=True
)

# Sort DataFrame based on categorical column
sorted_df = df.sort_values(by=column_name)

# Display result
print("\nSorted Data:")
print(sorted_df)
# Out:
# Enter CSV file path: employees.csv
# Enter column name to convert into category: Priority_Level
# Enter category order (comma-separated): Low, Medium, High
#
# Sorted Data:
#    Employee_ID   Name Department Priority_Level
# 2          103  Rahul    Finance            Low
# 4          105  Karan         HR            Low
# 6          107  Arjun         IT            Low
# 0          101   Amit         IT         Medium
# 5          106  Priya    Finance         Medium
# 7          108  Meera         HR         Medium
# 1          102   Neha         HR           High
# 3          104  Sneha         IT           High
# 8          109    Dev    Finance           High

# %% [markdown]
# ### Q10. Write a Python program that reads a CSV file containing sales data for different products and visualizes the data using a stacked bar chart to show the sales of each product category over time. The program should prompt the user to enter the file path and display the chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Take file path input
file_path = input("Enter CSV file path: ")

# Read CSV file
df = pd.read_csv(file_path)

# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Pivot data to prepare for stacked bar chart
pivot_df = df.pivot(index='Date', columns='Category', values='Sales')

# Plot stacked bar chart
pivot_df.plot(kind='bar', stacked=True)

# Labels and title
plt.title("Sales by Product Category Over Time")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.legend(title="Category")

# Show chart
plt.tight_layout()
plt.show()
# Out:
# Enter CSV file path: sales_data.csv

# %% [markdown]
# ### Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and displays the results in a table.
#
# The program should do the following:
#
# -> Prompt the user to enter the file path of the CSV file containing the student data.
#
# -> Read the CSV file into a Pandas DataFrame.
#
# -> Calculate the mean, median, and mode of the test   scores using Pandas tools.
#
# -> Display the mean, median, and mode in a table.
#
# Assume the CSV file contains the following columns:
#
# -> Student ID: The ID of the student.
#
# -> Test Score: The score of the student's test.
#
# Example usage of the program:
#
# Enter the file path of the CSV file containing the student data: student_data.csv
#
#
# | Statistic | Value  |
# | --------- | ------ |
# | Mean      | 79.6   |
# | Median    | 82     |
# | Mode      | 85, 90 |
#
# Assume that the CSV file student_data.csv contains the following data:
#
# Student ID,Test Score
#
# 1,85
#
# 2,90
#
# 3,80
#
# 4,75
#
# 5,85
#
# 6,82
#
# 7,78
#
# 8,85
#
# 9,90
#
# 10,85
#
# The program should calculate the mean, median, and mode of the test scores and display the results
# in a table.

# %%
import pandas as pd

# Prompt user for file path
file_path = input("Enter the file path of the CSV file containing the student data: ")

# Read CSV file
df = pd.read_csv(file_path)

# Calculate statistics
mean_score = df['Test Score'].mean()
median_score = df['Test Score'].median()
mode_score = df['Test Score'].mode()

# Convert mode values to comma-separated string
mode_value = ", ".join(map(str, mode_score))

# Create result table as DataFrame
result = pd.DataFrame({
    "Statistic": ["Mean", "Median", "Mode"],
    "Value": [round(mean_score, 2), median_score, mode_value]
})

# Display table
print("\nStatistics Table:\n")
print(result.to_string(index=False))
# Out:
# Enter the file path of the CSV file containing the student data: student_data.csv
#
# Statistics Table:
#
# Statistic  Value
#      Mean  83.33
#    Median   85.0
#      Mode     85
