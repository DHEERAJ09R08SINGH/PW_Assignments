# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.
#
# Ans:
#
# a)What is Matplotlib?
#
# ->Matplotlib is a popular data visualization library in Python used to create static, animated, and interactive graphs and charts.
# It is especially used with libraries like NumPy and Pandas for data analysis and visualization.
#
# The most commonly used module in Matplotlib is matplotlib.pyplot, which provides a MATLAB-like interface for plotting.
#
# b)Why is Matplotlib Used?
#
# ->Matplotlib is used for:
#
# 1)📊 Visualizing data in graphical format
#
# 2)📈 Analyzing trends and patterns
#
# 3)📉 Comparing datasets
#
# 4)📋 Creating professional charts for reports & dashboards
#
# 5)🎓 Educational and research purposes
#
# It helps convert raw data into meaningful insights through visual representation.
#
# c)Five Plots Using Pyplot Module:
#
# ->Five commonly used plots created using the Pyplot module:
#
# 1)Line Plot: Used to show trends over time.
#
# Function: plt.plot()
#
# 2)Bar Plot: Used to compare categories.
#
# Function: plt.bar()
#
# 3)Histogram: Used to show frequency distribution of data.
#
# Function: plt.hist()
#
# 4)Scatter Plot: Used to show relationship between two variables.
#
# Function: plt.scatter()
#
# 5)Pie Chart: Used to show percentage distribution.
#
# Function: plt.pie()

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data, plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.
#
# Ans:
#
# A scatter plot is a type of graph used to display the relationship between two numerical variables.
# Each point on the graph represents one observation in the dataset.
#
# plt.scatter(x, y)

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)
plt.title("Scatter Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
#
# Ans:
#
# The subplot() function in Matplotlib (Pyplot module) is used to create multiple plots (graphs) in a single figure window.
#
# plt.subplot(nrows, ncols, index)
#
# It helps display different graphs together for easy comparison.
#
# ✅ Purpose of subplot()
#
# 📊 To show multiple plots in one figure
#
# 📈 To compare different datasets
#
# 📉 To organize plots in a grid format
#
# 📋 To create dashboards or combined visualizations

# %%
import numpy as np
import matplotlib.pyplot as plt

# Line 1
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])

# Line 2
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

# Line 3
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

# Line 4
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create 2x2 subplot layout
plt.figure(figsize=(10,8))

plt.subplot(2, 2, 1)
plt.plot(x1, y1)
plt.title("Line 1")

plt.subplot(2, 2, 2)
plt.plot(x2, y2)
plt.title("Line 2")

plt.subplot(2, 2, 3)
plt.plot(x3, y3)
plt.title("Line 3")

plt.subplot(2, 2, 4)
plt.plot(x4, y4)
plt.title("Line 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])
#
# Ans:
#
# ->A bar plot (bar chart) is a graph that represents data using rectangular bars, where the length or height of each bar corresponds to the value it represents.
#
# plt.bar(x, y)
#
# X-axis → Categories
#
# Y-axis → Numerical values
#
# ->Why is a Bar Plot Used?
#
# A bar plot is used to:
#
# 📊 Compare values between different categories
#
# 📈 Show differences clearly and visually
#
# 📉 Analyze trends in categorical data
#
# 📋 Present survey or grouped data results

# %%
import numpy as np

company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)
#
# Ans:
#
# A box plot (also called a box-and-whisker plot) is a graphical representation that shows the distribution of numerical data
# using five summary statistics:
#
# 1)Minimum
#
# 2)First Quartile (Q1)
#
# 3)Median (Q2)
#
# 4)Third Quartile (Q3)
#
# 5)Maximum
#
# plt.boxplot(data)

# %%
box1 = np.random.normal(100, 10, 200)

box2 = np.random.normal(90, 20, 200)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate random data
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# Create box plot
plt.boxplot([box1, box2])

# Add labels
plt.xticks([1, 2], ["Box 1", "Box 2"])
plt.title("Box Plot Example")
plt.ylabel("Values")

plt.show()
